# %% [markdown]
# ## Deteccion piedra papel o tijera
# En esta tarea, utilizaremos yolo11, para poder indetificar los 3 posibles casos que se pueden dar. Para ello hemos descargado el siguiente dataset de RoboFlow.
#
# https://universe.roboflow.com/roboflow-58fyf/rock-paper-scissors-sxsw/dataset/14
#
# Una vez descargado, vamos a crear la estructura necesaria para asi poder trabajar correctamente con YOLO.

# %%
# !label-studio
# Out:
# => Database and media directory: /home/ciabd10/.local/share/label-studio
# => Static URL is set to: /static/
# => Database and media directory: /home/ciabd10/.local/share/label-studio
# => Static URL is set to: /static/
# Read environment variables from: /home/ciabd10/.local/share/label-studio/.env
# get 'SECRET_KEY' casted as '<class 'str'>' with default ''
# NumExpr defaulting to 16 threads.
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /pypi/label-studio/json HTTP/1.1" 200 39017
# /home/ciabd10/anaconda3/lib/python3.13/site-packages/django/db/backends/utils.py:98: RuntimeWarning: Accessing the database during app initialization is discouraged. To fix this warning, avoid executing queries in AppConfig.ready() or when your app modules are imported.
#   warnings.warn(self.APPS_NOT_READY_WARNING_MSG, category=RuntimeWarning)
# January 21, 2026 - 14:54:47
# Django version 5.1.15, using settings 'label_studio.core.settings.label_studio'
# Starting development server at http://0.0.0.0:8080/
# Quit the server with CONTROL-C.
#
# [2026-01-21 14:54:50,865] [django.server::log_message::213] [INFO] "GET / HTTP/1.1" 200 40930
# [2026-01-21 14:54:50,865] [django.server::log_message::213] [INFO] "GET / HTTP/1.1" 200 40930
# [2026-01-21 14:54:50,923] [django.server::log_message::213] [INFO] "GET /react-app/runtime.js?v=090298 HTTP/1.1" 200 6177
# [2026-01-21 14:54:50,923] [django.server::log_message::213] [INFO] "GET /react-app/runtime.js?v=090298 HTTP/1.1" 200 6177
# [2026-01-21 14:54:50,932] [django.server::log_message::213] [INFO] "GET /static/fonts/Figtree-Regular.ttf HTTP/1.1" 200 40584
# [2026-01-21 14:54:50,932] [django.server::log_message::213] [INFO] "GET /static/fonts/Figtree-Regular.ttf HTTP/1.1" 200 40584
# [2026-01-21 14:54:50,933] [django.server::log_message::213] [INFO] "GET /static/fonts/Figtree-SemiBold.ttf HTTP/1.1" 200 40852
# [2026-01-21 14:54:50,933] [django.server::log_message::213] [INFO] "GET /static/fonts/Figtree-SemiBold.ttf HTTP/1.1" 200 40852
# [2026-01-21 14:54:50,940] [django.server::log_message::213] [INFO] "GET /static/js/jquery.min.e6c2415c0ace.js HTTP/1.1" 200 87462
# [2026-01-21 14:54:50,940] [django.server::log_message::213] [INFO] "GET /static/js/jquery.min.e6c2415c0ace.js HTTP/1.1" 200 87462
# [2026-01-21 14:54:50,965] [django.server::log_message::213] [INFO] "GET /react-app/main.css?v=090298 HTTP/1.1" 200 191958
# [2026-01-21 14:54:50,965] [django.server::log_message::213] [INFO] "GET /react-app/main.css?v=090298 HTTP/1.1" 200 191958
# [2026-01-21 14:54:51,182] [django.server::log_message::213] [INFO] "GET /sw.js HTTP/1.1" 200 6221
# [2026-01-21 14:54:51,182] [django.server::log_message::213] [INFO] "GET /sw.js HTTP/1.1" 200 6221
# [2026-01-21 14:54:51,217] [django.server::log_message::213] [INFO] "GET /react-app/vendor.js?v=1 HTTP/1.1" 200 277253
# [2026-01-21 14:54:51,217] [django.server::log_message::213] [INFO] "GET /react-app/vendor.js?v=1 HTTP/1.1" 200 277253
# [2026-01-21 14:54:51,263] [django.server::log_message::213] [INFO] "GET /react-app/main.js?v=090298 HTTP/1.1" 200 2112168
# [2026-01-21 14:54:51,263] [django.server::log_message::213] [INFO] "GET /react-app/main.js?v=090298 HTTP/1.1" 200 2112168
# [2026-01-21 14:54:51,574] [django.server::log_message::213] [INFO] "GET /api/version HTTP/1.1" 200 1015
# [2026-01-21 14:54:51,574] [django.server::log_message::213] [INFO] "GET /api/version HTTP/1.1" 200 1015
# [2026-01-21 14:54:51,590] [django.server::log_message::213] [INFO] "GET /api/current-user/whoami HTTP/1.1" 200 1233
# [2026-01-21 14:54:51,590] [django.server::log_message::213] [INFO] "GET /api/current-user/whoami HTTP/1.1" 200 1233
# [2026-01-21 14:54:51,615] [django.server::log_message::213] [INFO] "GET /api/projects?page_size=10 HTTP/1.1" 200 2132
# [2026-01-21 14:54:51,615] [django.server::log_message::213] [INFO] "GET /api/projects?page_size=10 HTTP/1.1" 200 2132
# [2026-01-21 14:54:51,630] [django.server::log_message::213] [INFO] "GET /heidi-tips HTTP/1.1" 200 9982
# [2026-01-21 14:54:51,630] [django.server::log_message::213] [INFO] "GET /heidi-tips HTTP/1.1" 200 9982
# [2026-01-21 14:54:51,655] [django.server::log_message::213] [INFO] "GET /static/images/favicon.8992b8aa4126.ico HTTP/1.1" 200 15406
# [2026-01-21 14:54:51,655] [django.server::log_message::213] [INFO] "GET /static/images/favicon.8992b8aa4126.ico HTTP/1.1" 200 15406
# [2026-01-21 14:54:52,406] [django.server::log_message::213] [INFO] "GET /sw.js HTTP/1.1" 200 6221
# [2026-01-21 14:54:52,406] [django.server::log_message::213] [INFO] "GET /sw.js HTTP/1.1" 200 6221
# ^C

# %% [markdown]
# Empezamos con el entrenamiento, en primer lugar vamos a usar el modelo que hemos decargado.

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

results = model.train(
    data="data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.6 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.234 🚀 Python-3.13.5 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12044MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820569  ultralytics.nn.modules.head.Detect           [3, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,953 parameters, 9,428,937 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 32.7MB/s 0.2s.1s<0.2s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2814.3±1295.8 MB/s, size: 32.6 KB)
# train: Scanning /home/ciabd10/Descargas/MIA/Actividad_5/dataset/train/labels... 6455 images, 2516 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6455/6455 4.4Kit/s 1.5s0.1s
# train: New cache created: /home/ciabd10/Descargas/MIA/Actividad_5/dataset/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1872.8±886.0 MB/s, size: 31.7 KB)
# val: Scanning /home/ciabd10/Descargas/MIA/Actividad_5/dataset/valid/labels... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576 4.8Kit/s 0.1s0.1s
# val: New cache created: /home/ciabd10/Descargas/MIA/Actividad_5/dataset/valid/labels.cache
# Plotting labels to /home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/train2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      3.97G       1.36      2.612      1.529          6        640: 100% ━━━━━━━━━━━━ 404/404 4.6it/s 1:28<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s0.1s
#                    all        576        400      0.335      0.324      0.261       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      4.74G      1.524      2.095      1.636         13        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:13<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        576        400      0.487       0.36      0.402      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30       4.8G      1.497       1.95      1.603          3        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.6s0.1s
#                    all        576        400      0.734      0.442      0.546       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      4.84G       1.43      1.824      1.544         11        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        576        400       0.67       0.58      0.659      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      4.88G      1.328       1.62      1.469          5        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        576        400      0.765      0.679      0.776      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      4.92G      1.274      1.478      1.425          5        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        576        400      0.759      0.653      0.753      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      4.96G      1.222      1.372      1.388          3        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        576        400      0.858      0.771      0.854      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30         5G      1.169      1.268      1.361          5        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        576        400      0.709      0.762      0.809      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      5.04G      1.113      1.193      1.323          4        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        576        400      0.787        0.8      0.841      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      5.08G      1.104      1.149      1.315          9        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400        0.9      0.815      0.904      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      5.12G      1.086      1.106      1.299          8        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.868      0.838      0.892      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      5.16G      1.047      1.046      1.274          9        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.905      0.848      0.909      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30       5.2G      1.026     0.9824      1.254          6        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        576        400      0.857      0.889      0.912      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      5.24G      1.001     0.9682      1.238          6        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        576        400      0.897      0.863       0.92      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      5.28G     0.9751     0.9056      1.225          7        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        576        400      0.906      0.887      0.926      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      5.32G     0.9639     0.9064      1.215          4        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        576        400      0.912      0.866       0.92      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      5.36G     0.9504     0.8611      1.212          6        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.935      0.868      0.939      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30       5.4G     0.9288     0.8439      1.199         17        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.925       0.91      0.946      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      5.44G     0.9025     0.7941      1.181          9        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.921      0.916      0.942      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      5.48G     0.8854     0.7706      1.166         10        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400       0.94      0.889      0.942      0.741
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      5.52G     0.7752     0.5319      1.109          6        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        576        400      0.939      0.897      0.945      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      5.56G     0.7556     0.4966      1.097          6        640: 100% ━━━━━━━━━━━━ 404/404 5.6it/s 1:12<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.933      0.899       0.94      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30       5.6G     0.7234     0.4659      1.078          2        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.914      0.926      0.949      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      5.64G     0.6898     0.4449      1.054          4        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        576        400      0.953      0.892       0.95       0.76
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      5.68G     0.6746     0.4281      1.047          3        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        576        400       0.94      0.913       0.95      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      5.72G     0.6564     0.4024      1.031          5        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        576        400      0.946      0.915      0.959      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      5.76G     0.6365     0.3844      1.018          5        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        576        400      0.936      0.917       0.95      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30       5.8G     0.6147     0.3577      1.008          5        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        576        400      0.953      0.927      0.964      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      5.84G     0.5806     0.3485     0.9805          6        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        576        400      0.966      0.923       0.96      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      5.88G     0.5707     0.3342     0.9841          5        640: 100% ━━━━━━━━━━━━ 404/404 5.7it/s 1:11<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        576        400      0.951      0.927       0.96      0.785
#
# 30 epochs completed in 0.629 hours.
# Optimizer stripped from /home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/train2/weights/last.pt, 19.2MB
# Optimizer stripped from /home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/train2/weights/best.pt, 19.2MB
#
# Validating /home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.234 🚀 Python-3.13.5 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12044MiB)
# YOLO11s summary (fused): 100 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        576        400      0.966      0.923       0.96      0.787
#                  Paper        132        139      0.992      0.935      0.969      0.798
#                   Rock        121        141       0.95      0.943      0.959      0.776
#               Scissors        116        120      0.955      0.889      0.952      0.787
# Speed: 0.1ms preprocess, 3.1ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/train2

# %% [markdown]
# Después de haber entrenado el modelo, recogeremos el resultado y comprobaremos si el entrenamiento fue bueno o no. Es decir, si de verdad sirve para poder identificar los 3 estados (piedra, papel o tijera).

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")
metrics = model.val(data="data.yaml", imgsz=640, device=0)
# Out:
# Ultralytics 8.3.234 🚀 Python-3.13.5 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12044MiB)
# YOLO11s summary (fused): 100 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2810.7±1443.8 MB/s, size: 29.5 KB)
# val: Scanning /home/ciabd10/Descargas/MIA/Actividad_5/dataset/valid/labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576 1.5Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 36/36 9.0it/s 4.0s0.1s
#                    all        576        400      0.966      0.922       0.96      0.788
#                  Paper        132        139      0.992      0.934      0.969        0.8
#                   Rock        121        141       0.95      0.943       0.96      0.777
#               Scissors        116        120      0.955       0.89      0.953      0.787
# Speed: 0.5ms preprocess, 5.3ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/ciabd10/Descargas/MIA/Actividad_5/runs/detect/val
