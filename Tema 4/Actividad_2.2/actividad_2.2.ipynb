# %% [markdown]
# ### Whisper con Groq

# %%
# Instalar la librería oficial de Groq
# %pip install groq

# Instalar python-dotenv para la gestión de variables
# %pip install python-dotenv
# Out:
# Collecting groq
#   Downloading groq-1.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from groq) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from groq) (2.10.3)
# Requirement already satisfied: sniffio in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: certifi in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->groq) (2.27.1)
# Downloading groq-1.1.1-py3-none-any.whl (139 kB)
# Installing collected packages: groq
# Successfully installed groq-1.1.1
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /home/ciabd10/anaconda3/lib/python3.13/site-packages (1.1.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
# Cargar variables del archivo .env
load_dotenv()

# La variable queda disponible en el sistema automáticamente
# Out:
# True

# %% [markdown]
# #### Implementacion en Python

# %%
import os
from groq import Groq

# Inicializar el cliente de Groq
client = Groq()

# Definir la ruta del archivo de audio
filename = "prueba_larga_whisper.mp3"

# Proceso de apertura y transcripción
with open(filename, "rb") as file:
    transcription = client.audio.transcriptions.create(
        file=file, # Archivo de audio binario
        model="whisper-large-v3-turbo", # Modelo seleccionado
        prompt="Contexto o palabras clave", # Opcional para mejorar precisión
        response_format="verbose_json", # Formato detallado de salida
        language="es", # Idioma del audio (ISO-639-1)
        temperature=0.0 # Mayor determinismo (0.0)
)

# Resultado final
print(transcription.text)
# Out:
#  Hola, esta es una prueba de audio un poco más larga para verificar el funcionamiento de Whisper. Estoy hablando en español con una velocidad normal y con frases sencillas para que el modelo pueda reconocer bien las palabras. Este archivo sirve para comprobar la transcripción, la puntuación y también el comportamiento general del sistema con una muestra de voz continua. Si todo funciona correctamente, el resultado debería parecerse bastante al texto original, aunque puede haber pequeñas diferencias en algunas palabras o en los signos de puntuación Esta prueba también puede ayudar a comparar distintos modelos, configuraciones o niveles de compresión de audio
