# %% [markdown]
# ## Práctica Tokenización

# %% [markdown]
# #### Preparación inicial del texto

# %%
# Definimos nuestra variable de texto
texto = "Tengo un perro verde y un gato azul"
# Convertimos a minúsculas
texto_minusculas = texto.lower()
print(f"Texto en minúsculas: {texto_minusculas}")
# División básica con split (basada en espacios)
tokens_basicos = texto_minusculas.split()
print(f"Tokens con split(): {tokens_basicos}")
print(f"Número de tokens: {len(tokens_basicos)}")
# Out:
# Texto en minúsculas: tengo un perro verde y un gato azul
# Tokens con split(): ['tengo', 'un', 'perro', 'verde', 'y', 'un', 'gato', 'azul']
# Número de tokens: 8

# %% [markdown]
# #### Configuración NLTK

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Descargamos los recursos necesarios
nltk.download('punkt')
nltk.download('punkt_tab')
# punkt es el "cerebro" que le enseña a NLTK a dividir un texto en palabras y frases de 
# forma gramaticalmente correcta, y no solo cortando por espacios.
nltk.download('stopwords') #palabras irrelevantes
# Out:
# [nltk_data] Downloading package punkt to /home/ciabd10/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/ciabd10/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ciabd10/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
import os

# Obtenemos la ruta de la carpeta nltk_data que se ve en tu imagen
ruta_local = os.path.join(os.getcwd(), 'nltk_data')

# La añadimos a las rutas de búsqueda de NLTK
nltk.data.path.append(ruta_local)

# %% [markdown]
# #### Exploración Stop Words

# %%
# Listar todos los idiomas/opciones disponibles en el corpus de stopwords
print("Idiomas y opciones disponibles en NLTK Stopwords:")
print(stopwords.fileids())
# Out:
# Idiomas y opciones disponibles en NLTK Stopwords:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %% [markdown]
# #### Tokenización Avanzada

# %%
# Tokenizamos el texto original (en minúsculas)
tokens = word_tokenize(texto_minusculas)
print("Resultado de word_tokenize:")
print(tokens)
# Out:
# Resultado de word_tokenize:
# ['tengo', 'un', 'perro', 'verde', 'y', 'un', 'gato', 'azul']

# %% [markdown]
# #### Filtrado de Stop Words

# %%
# Filtramos: "Crea una lista con cada palabra de 'tokens' si esa palabra NO está en 'stop_words'"
stop_words = []

texto_filtrado = [word for word in tokens if word not in stop_words]
print("Resultado final (sin Stop Words):")
print(texto_filtrado)

# Comparativa de longitud
print(f"\nLongitud original: {len(tokens)} palabras")
print(f"Longitud tras filtrado: {len(texto_filtrado)} palabras")
# Out:
# Resultado final (sin Stop Words):
# ['tengo', 'un', 'perro', 'verde', 'y', 'un', 'gato', 'azul']
#
# Longitud original: 8 palabras
# Longitud tras filtrado: 8 palabras

# %% [markdown]
# ## Stemming y Lemmatización en Español

# %% [markdown]
# #### Stemming

# %%
import nltk

# Wordnet es un diccionario inteligente que le permite a NLTK saber que un 'perrito' es 
# un 'animal' y que 'corriendo' es una acción derivada de 'correr'."
nltk.download('wordnet')

from nltk.stem import SnowballStemmer

# Configuramos el stemmer para español
stemmer = SnowballStemmer('spanish')

# Lista de palabras de prueba (verbos y sustantivos)
palabras = ['correr', 'corriendo', 'corredor', 'perros', 'perrito',
'casas', 'casita']
print("--- RESULTADO DEL STEMMING ---")
for p in palabras:
 raiz = stemmer.stem(p)
 print(f"{p} -> {raiz}")
# Out:
# [nltk_data] Downloading package wordnet to /home/ciabd10/nltk_data...
# --- RESULTADO DEL STEMMING ---
# correr -> corr
# corriendo -> corr
# corredor -> corredor
# perros -> perr
# perrito -> perrit
# casas -> cas
# casita -> casit

# %% [markdown]
# #### Instalación necesaria para Lemmatización

# %%
# Ejecuta esto en una celda si no lo tienes
# %pip install spacy
# %python -m spacy download es_core_news_sm
# Out:
# Collecting spacy
#   Downloading spacy-3.8.11-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.12-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.10-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.5 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer>=0.24.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.1)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.0)
# Requirement already satisfied: rich>=12.3.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ciabd10/anaconda3/lib/python3.13/site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.11-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 3.9 MB/s  0:00:08m0:00:0100:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (254 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (133 kB)
# Downloading preshed-3.0.12-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (835 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 835.9/835.9 kB 3.5 MB/s  0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.4 MB/s  0:00:00
# Downloading thinc-8.3.10-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 10.1 MB/s  0:00:00 eta 0:00:01
# Downloading blis-1.3.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 13.0 MB/s  0:00:00m0:00:010:01
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, murmurhash, cymem, cloudpathlib, catalogue, blis, srsly, preshed, confection, thinc, weasel, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [spacy]m13/14 [spacy]]ion]b]
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.12 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 wasabi-1.1.3 weasel-0.4.3
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).

# %% [markdown]
# #### Lemmatizacion en Español con Spacy

# %%
import spacy

# Cargamos el modelo en español

import spacy.cli
spacy.cli.download("es_core_news_sm")
nlp = spacy.load("es_core_news_sm")

# Nuestra frase original
texto = "Tengo un perro verde y un gato azul. Los perros están corriendo."

# Procesamos el texto
doc = nlp(texto)
print("--- RESULTADO DE LA LEMMATIZACIÓN ---")

# Imprimimos: Palabra original -> Lema (Raíz de diccionario)
for token in doc:
 print(f"{token.text} -> {token.lemma_}")
# Out:
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 31.2 MB/s  0:00:00m0:00:010:01
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# --- RESULTADO DE LA LEMMATIZACIÓN ---
# Tengo -> tener
# un -> uno
# perro -> perro
# verde -> verde
# y -> y
# un -> uno
# gato -> gato
# azul -> azul
# . -> .
# Los -> el
# perros -> perro
# están -> estar
# corriendo -> correr
# . -> .

# %% [markdown]
# #### Comparativa para ambos procesos

# %%
frase = "Los gatos están durmiendo en las alfombras"
tokens = word_tokenize(frase.lower()) # Usando lo que aprendimos antes
print(f"{'PALABRA':<15} | {'STEMMING':<15} | {'LEMA'}")
print("-" * 45)
for t in tokens:
 # Stemming con NLTK
 st = stemmer.stem(t)

 # Lema con spaCy (procesamos la palabra individualmente)
 lm = nlp(t)[0].lemma_

 print(f"{t:<15} | {st:<15} | {lm}")
# Out:
# PALABRA         | STEMMING        | LEMA
# ---------------------------------------------
# los             | los             | el
# gatos           | gat             | gato
# están           | estan           | estar
# durmiendo       | durm            | dormir
# en              | en              | en
# las             | las             | el
# alfombras       | alfombr         | alfombra

# %% [markdown]
# #### Encontrar sinónimos

# %%
from nltk.corpus import wordnet

# Buscamos el concepto de "perro" (dog)
syns = wordnet.synsets("dog")

# Ver el nombre del concepto y su definición
print(f"Concepto: {syns[0].name()}")
print(f"Definición: {syns[0].definition()}")

# Ver sinónimos
print(f"Sinónimos: {syns[0].lemma_names()}")
# Out:
# Concepto: dog.n.01
# Definición: a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds
# Sinónimos: ['dog', 'domestic_dog', 'Canis_familiaris']
